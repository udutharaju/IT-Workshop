# %%
from matplotlib import pyplot as plt
import numpy as np
x= np.arange(0,3*np.pi,0.1)
y= np.sin(x)

plt.scatter(x,y,color = "blue",label = "data1")
x= np.arange(0,3*np.pi,0.1)
y= np.cos(x)
plt.scatter(x,y,color = "red",marker = "s",label = "data2")
plt.legend(loc="upper right")
