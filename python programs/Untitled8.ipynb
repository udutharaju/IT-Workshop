# %%
from matplotlib import pyplot as plt
import numpy as np
x= [12,34,56,78]
y = [290,450,362,763]
c = ["yellow","blue","red","pink"]
plt.bar(x,y,color=c)
plt.title("pie chart")
plt.legend(title ="x")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from matplotlib import pyplot as plt
import numpy as np
x= [12,34,56,78]
y = [290,450,362,763]
plt.grid()
plt.plot(x,y)

# %%
from matplotlib import pyplot as plt
import numpy as np
from scipy.ndimage import convolve
image = plt.imread("/home/raju/rgukt.jpeg")
plt.imshow(image)
